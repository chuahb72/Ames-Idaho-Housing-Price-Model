# %% [markdown]
# # <font color='green'>Import modules</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %matplotlib inline

# %%
# Configure Pandas to show all columns
pd.set_option("display.max.columns", None)

# %% [markdown]
# # <font color='green'>Read Train and Test datasets</font>

# %%
# read train and test datasets
train_set = pd.read_csv("../datasets/Output Data/train_noNull.csv")
test_set = pd.read_csv("../datasets/Output Data/test_noNull.csv")

# %%
# inspect rows and columns count
print(train_set.shape)
print(test_set.shape)
# Out:
# (2046, 79)
# (879, 78)

# %%
# check dtypes and nulls in train set
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2046 entries, 0 to 2045
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2046 non-null   int64
#  1   pid              2046 non-null   int64
#  2   ms_subclass      2046 non-null   int64
#  3   ms_zoning        2046 non-null   object
#  4   lot_area         2046 non-null   int64
#  5   street           2046 non-null   object
#  6   lot_shape        2046 non-null   object
#  7   land_contour     2046 non-null   object
#  8   utilities        2046 non-null   object
#  9   lot_config       2046 non-null   object
#  10  land_slope       2046 non-null   object
#  11  neighborhood     2046 non-null   object
#  12  condition_1      2046 non-null   object
#  13  condition_2      2046 non-null   object
#  14  bldg_type        2046 non-null   object
#  15  house_style      2046 non-null   object
#  16  overall_qual     2046 non-null   int64
#  17  overall_cond     2046 non-null   int64
#  18  year_built       2046 non-null   int64
#  19  year_remod/add   2046 non-null   int64
#  20  roof_style       2046 non-null   object
#  21  roof_matl        2046 non-null   object
#  22  exterior_1st     2046 non-null   object
#  23  exterior_2nd     2046 non-null   object
#  24  mas_vnr_type     2046 non-null   object
#  25  mas_vnr_area     2046 non-null   float64
#  26  exter_qual       2046 non-null   object
#  27  exter_cond       2046 non-null   object
#  28  foundation       2046 non-null   object
#  29  bsmt_qual        2046 non-null   object
#  30  bsmt_cond        2046 non-null   object
#  31  bsmt_exposure    2046 non-null   object
#  32  bsmtfin_type_1   2046 non-null   object
#  33  bsmtfin_sf_1     2046 non-null   float64
#  34  bsmtfin_type_2   2046 non-null   object
#  35  bsmtfin_sf_2     2046 non-null   float64
#  36  bsmt_unf_sf      2046 non-null   float64
#  37  total_bsmt_sf    2046 non-null   float64
#  38  heating          2046 non-null   object
#  39  heating_qc       2046 non-null   object
#  40  central_air      2046 non-null   object
#  41  electrical       2046 non-null   object
#  42  1st_flr_sf       2046 non-null   int64
#  43  2nd_flr_sf       2046 non-null   int64
#  44  low_qual_fin_sf  2046 non-null   int64
#  45  gr_liv_area      2046 non-null   int64
#  46  bsmt_full_bath   2046 non-null   float64
#  47  bsmt_half_bath   2046 non-null   float64
#  48  full_bath        2046 non-null   int64
#  49  half_bath        2046 non-null   int64
#  50  bedroom_abvgr    2046 non-null   int64
#  51  kitchen_abvgr    2046 non-null   int64
#  52  kitchen_qual     2046 non-null   object
#  53  totrms_abvgrd    2046 non-null   int64
#  54  functional       2046 non-null   object
#  55  fireplaces       2046 non-null   int64
#  56  fireplace_qu     2046 non-null   object
#  57  garage_type      2046 non-null   object
#  58  garage_yr_blt    2046 non-null   float64
#  59  garage_finish    2046 non-null   object
#  60  garage_cars      2046 non-null   float64
#  61  garage_area      2046 non-null   float64
#  62  garage_qual      2046 non-null   object
#  63  garage_cond      2046 non-null   object
#  64  paved_drive      2046 non-null   object
#  65  wood_deck_sf     2046 non-null   int64
#  66  open_porch_sf    2046 non-null   int64
#  67  enclosed_porch   2046 non-null   int64
#  68  3ssn_porch       2046 non-null   int64
#  69  screen_porch     2046 non-null   int64
#  70  pool_area        2046 non-null   int64
#  71  pool_qc          2046 non-null   object
#  72  fence            2046 non-null   object
#  73  misc_feature     2046 non-null   object
#  74  misc_val         2046 non-null   int64
#  75  mo_sold          2046 non-null   int64
#  76  yr_sold          2046 non-null   int64
#  77  sale_type        2046 non-null   object
#  78  saleprice        2046 non-null   int64
# dtypes: float64(10), int64(28), object(41)
# memory usage: 1.2+ MB

# %%
# check dtypes and nulls in test set
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 78 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               879 non-null    int64
#  1   pid              879 non-null    int64
#  2   ms_subclass      879 non-null    int64
#  3   ms_zoning        879 non-null    object
#  4   lot_area         879 non-null    int64
#  5   street           879 non-null    object
#  6   lot_shape        879 non-null    object
#  7   land_contour     879 non-null    object
#  8   utilities        879 non-null    object
#  9   lot_config       879 non-null    object
#  10  land_slope       879 non-null    object
#  11  neighborhood     879 non-null    object
#  12  condition_1      879 non-null    object
#  13  condition_2      879 non-null    object
#  14  bldg_type        879 non-null    object
#  15  house_style      879 non-null    object
#  16  overall_qual     879 non-null    int64
#  17  overall_cond     879 non-null    int64
#  18  year_built       879 non-null    int64
#  19  year_remod/add   879 non-null    int64
#  20  roof_style       879 non-null    object
#  21  roof_matl        879 non-null    object
#  22  exterior_1st     879 non-null    object
#  23  exterior_2nd     879 non-null    object
#  24  mas_vnr_type     879 non-null    object
#  25  mas_vnr_area     879 non-null    float64
#  26  exter_qual       879 non-null    object
#  27  exter_cond       879 non-null    object
#  28  foundation       879 non-null    object
#  29  bsmt_qual        879 non-null    object
#  30  bsmt_cond        879 non-null    object
#  31  bsmt_exposure    879 non-null    object
#  32  bsmtfin_type_1   879 non-null    object
#  33  bsmtfin_sf_1     879 non-null    int64
#  34  bsmtfin_type_2   879 non-null    object
#  35  bsmtfin_sf_2     879 non-null    int64
#  36  bsmt_unf_sf      879 non-null    int64
#  37  total_bsmt_sf    879 non-null    int64
#  38  heating          879 non-null    object
#  39  heating_qc       879 non-null    object
#  40  central_air      879 non-null    object
#  41  electrical       879 non-null    object
#  42  1st_flr_sf       879 non-null    int64
#  43  2nd_flr_sf       879 non-null    int64
#  44  low_qual_fin_sf  879 non-null    int64
#  45  gr_liv_area      879 non-null    int64
#  46  bsmt_full_bath   879 non-null    int64
#  47  bsmt_half_bath   879 non-null    int64
#  48  full_bath        879 non-null    int64
#  49  half_bath        879 non-null    int64
#  50  bedroom_abvgr    879 non-null    int64
#  51  kitchen_abvgr    879 non-null    int64
#  52  kitchen_qual     879 non-null    object
#  53  totrms_abvgrd    879 non-null    int64
#  54  functional       879 non-null    object
#  55  fireplaces       879 non-null    int64
#  56  fireplace_qu     879 non-null    object
#  57  garage_type      879 non-null    object
#  58  garage_yr_blt    879 non-null    float64
#  59  garage_finish    879 non-null    object
#  60  garage_cars      879 non-null    int64
#  61  garage_area      879 non-null    int64
#  62  garage_qual      879 non-null    object
#  63  garage_cond      879 non-null    object
#  64  paved_drive      879 non-null    object
#  65  wood_deck_sf     879 non-null    int64
#  66  open_porch_sf    879 non-null    int64
#  67  enclosed_porch   879 non-null    int64
#  68  3ssn_porch       879 non-null    int64
#  69  screen_porch     879 non-null    int64
#  70  pool_area        879 non-null    int64
#  71  pool_qc          879 non-null    object
#  72  fence            879 non-null    object
#  73  misc_feature     879 non-null    object
#  74  misc_val         879 non-null    int64
#  75  mo_sold          879 non-null    int64
#  76  yr_sold          879 non-null    int64
#  77  sale_type        879 non-null    object
# dtypes: float64(2), int64(35), object(41)
# memory usage: 535.8+ KB

# %%
train_set.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 0  109  533352170           60        RL     13517   Pave       IR1
# 1  544  531379050           60        RL     11492   Pave       IR1
# 2  153  535304180           20        RL      7922   Pave       Reg
# 3  318  916386060           60        RL      9802   Pave       Reg
# 4  255  906425045           50        RL     14235   Pave       IR1
#
#   land_contour utilities lot_config land_slope neighborhood condition_1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 2          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 4          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
#
#   condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 0        Norm      1Fam      2Story             6             8        1976
# 1        Norm      1Fam      2Story             7             5        1996
# 2        Norm      1Fam      1Story             5             7        1953
# 3        Norm      1Fam      2Story             5             5        2006
# 4        Norm      1Fam      1.5Fin             6             8        1900
#
#    year_remod/add roof_style roof_matl exterior_1st exterior_2nd mas_vnr_type  \
# 0            2005      Gable   CompShg      HdBoard      Plywood      BrkFace
# 1            1997      Gable   CompShg      VinylSd      VinylSd      BrkFace
# 2            2007      Gable   CompShg      VinylSd      VinylSd         None
# 3            2007      Gable   CompShg      VinylSd      VinylSd         None
# 4            1993      Gable   CompShg      Wd Sdng      Plywood         None
#
#    mas_vnr_area exter_qual exter_cond foundation bsmt_qual bsmt_cond  \
# 0         289.0         Gd         TA     CBlock        TA        TA
# 1         132.0         Gd         TA      PConc        Gd        TA
# 2           0.0         TA         Gd     CBlock        TA        TA
# 3           0.0         TA         TA      PConc        Gd        TA
# 4           0.0         TA         TA      PConc        Fa        Gd
#
#   bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  \
# 0            No            GLQ         533.0            Unf           0.0
# 1            No            GLQ         637.0            Unf           0.0
# 2            No            GLQ         731.0            Unf           0.0
# 3            No            Unf           0.0            Unf           0.0
# 4            No            Unf           0.0            Unf           0.0
#
#    bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air electrical  \
# 0        192.0          725.0    GasA         Ex           Y      SBrkr
# 1        276.0          913.0    GasA         Ex           Y      SBrkr
# 2        326.0         1057.0    GasA         TA           Y      SBrkr
# 3        384.0          384.0    GasA         Gd           Y      SBrkr
# 4        676.0          676.0    GasA         TA           Y      SBrkr
#
#    1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 0         725         754                0         1479             0.0
# 1         913        1209                0         2122             1.0
# 2        1057           0                0         1057             1.0
# 3         744         700                0         1444             0.0
# 4         831         614                0         1445             0.0
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 0             0.0          2          1              3              1
# 1             0.0          2          1              4              1
# 2             0.0          1          0              3              1
# 3             0.0          2          1              3              1
# 4             0.0          2          0              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 0           Gd              6        Typ           0         None      Attchd
# 1           Gd              8        Typ           1           TA      Attchd
# 2           Gd              5        Typ           0         None      Detchd
# 3           TA              7        Typ           0         None     BuiltIn
# 4           TA              6        Typ           0         None      Detchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 0         1976.0           RFn          2.0        475.0          TA
# 1         1997.0           RFn          2.0        559.0          TA
# 2         1953.0           Unf          1.0        246.0          TA
# 3         2007.0           Fin          2.0        400.0          TA
# 4         1957.0           Unf          2.0        484.0          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0          TA           Y             0             44               0
# 1          TA           Y             0             74               0
# 2          TA           Y             0             52               0
# 3          TA           Y           100              0               0
# 4          TA           N             0             59               0
#
#    3ssn_porch  screen_porch  pool_area pool_qc fence misc_feature  misc_val  \
# 0           0             0          0    None  None         None         0
# 1           0             0          0    None  None         None         0
# 2           0             0          0    None  None         None         0
# 3           0             0          0    None  None         None         0
# 4           0             0          0    None  None         None         0
#
#    mo_sold  yr_sold sale_type  saleprice
# 0        3     2010       WD      130500
# 1        4     2009       WD      220000
# 2        1     2010       WD      109000
# 3        4     2010       WD      174000
# 4        3     2010       WD      138500

# %%
test_set.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 0  2658  902301120          190        RM      9142   Pave       Reg
# 1  2718  905108090           90        RL      9662   Pave       IR1
# 2  2414  528218130           60        RL     17104   Pave       IR1
# 3  1989  902207150           30        RM      8520   Pave       Reg
# 4   625  535105100           20        RL      9500   Pave       IR1
#
#   land_contour utilities lot_config land_slope neighborhood condition_1  \
# 0          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 1          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 2          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 3          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 4          Lvl    AllPub     Inside        Gtl        NAmes        Norm
#
#   condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 0        Norm    2fmCon      2Story             6             8        1910
# 1        Norm    Duplex      1Story             5             4        1977
# 2        Norm      1Fam      2Story             7             5        2006
# 3        Norm      1Fam      1Story             5             6        1923
# 4        Norm      1Fam      1Story             6             5        1963
#
#    year_remod/add roof_style roof_matl exterior_1st exterior_2nd mas_vnr_type  \
# 0            1950      Gable   CompShg      AsbShng      AsbShng         None
# 1            1977      Gable   CompShg      Plywood      Plywood         None
# 2            2006      Gable   CompShg      VinylSd      VinylSd         None
# 3            2006      Gable   CompShg      Wd Sdng      Wd Sdng         None
# 4            1963      Gable   CompShg      Plywood      Plywood      BrkFace
#
#    mas_vnr_area exter_qual exter_cond foundation bsmt_qual bsmt_cond  \
# 0           0.0         TA         Fa      Stone        Fa        TA
# 1           0.0         TA         TA     CBlock        Gd        TA
# 2           0.0         Gd         TA      PConc        Gd        Gd
# 3           0.0         Gd         TA     CBlock        TA        TA
# 4         247.0         TA         TA     CBlock        Gd        TA
#
#   bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  \
# 0            No            Unf             0            Unf             0
# 1            No            Unf             0            Unf             0
# 2            Av            GLQ           554            Unf             0
# 3            No            Unf             0            Unf             0
# 4            No            BLQ           609            Unf             0
#
#    bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air electrical  \
# 0         1020           1020    GasA         Gd           N      FuseP
# 1         1967           1967    GasA         TA           Y      SBrkr
# 2          100            654    GasA         Ex           Y      SBrkr
# 3          968            968    GasA         TA           Y      SBrkr
# 4          785           1394    GasA         Gd           Y      SBrkr
#
#    1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  \
# 0         908        1020                0         1928               0
# 1        1967           0                0         1967               0
# 2         664         832                0         1496               1
# 3         968           0                0          968               0
# 4        1394           0                0         1394               1
#
#    bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  kitchen_abvgr  \
# 0               0          2          0              4              2
# 1               0          2          0              6              2
# 2               0          2          1              3              1
# 3               0          1          0              2              1
# 4               0          1          1              3              1
#
#   kitchen_qual  totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
# 0           Fa              9        Typ           0         None      Detchd
# 1           TA             10        Typ           0         None      Attchd
# 2           Gd              7        Typ           1           Gd      Attchd
# 3           TA              5        Typ           0         None      Detchd
# 4           TA              6        Typ           2           Gd      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
# 0         1910.0           Unf            1          440          Po
# 1         1977.0           Fin            2          580          TA
# 2         2006.0           RFn            2          426          TA
# 3         1935.0           Unf            2          480          Fa
# 4         1963.0           RFn            2          514          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
# 0          Po           Y             0             60             112
# 1          TA           Y           170              0               0
# 2          TA           Y           100             24               0
# 3          TA           N             0              0             184
# 4          TA           Y             0             76               0
#
#    3ssn_porch  screen_porch  pool_area pool_qc fence misc_feature  misc_val  \
# 0           0             0          0    None  None         None         0
# 1           0             0          0    None  None         None         0
# 2           0             0          0    None  None         None         0
# 3           0             0          0    None  None         None         0
# 4           0           185          0    None  None         None         0
#
#    mo_sold  yr_sold sale_type
# 0        4     2006       WD
# 1        8     2006       WD
# 2        9     2006       New
# 3        7     2007       WD
# 4        7     2009       WD

# %% [markdown]
# # <font color='green'>Review all train/test sets columns nulls/distribution/relationship with Sales price</font>

# %%
# Train_set saleprices

plt.figure(figsize=(10,6))

plt.hist(train_set['saleprice'], bins=25);

plt.xticks(fontsize=12);
plt.yticks(fontsize=12);
plt.xlabel("Sale Price", fontsize=15)
plt.ylabel("Frequency", fontsize=15)
plt.title("Sale Price Histogram", fontsize=20);
# plt.legend(["Others", "Real"], fontsize=10)

# %% [markdown]
# #### <font color='green'>Almost normally distributed with some very high price right skew</font>

# %%
train_set['saleprice'].describe()
# Out:
# count      2046.000000
# mean     181394.594330
# std       79311.974448
# min       12789.000000
# 25%      129575.000000
# 50%      162250.000000
# 75%      214000.000000
# max      611657.000000
# Name: saleprice, dtype: float64

# %%
# function for plotting train/test sets variable histograms and 
# train set scatter plot against saleprice
def var_hist_scatter(var_col):

    plt.figure(figsize=(10,6))

    plt.hist(train_set[var_col], bins=20, label="train_set", alpha=0.5)
    plt.hist(test_set[var_col], bins=20, label="test_set", alpha=0.5);

    plt.xticks(fontsize=12);
    plt.yticks(fontsize=12);
    plt.xlabel(var_col, fontsize=15)
    plt.ylabel("Frequency", fontsize=15)
    plt.title(var_col+" Histogram", fontsize=20)
    plt.legend(fontsize=15)

    plt.figure(figsize=(10,6))

    plt.scatter(train_set[var_col], train_set['saleprice'], s=5)

    plt.xticks(fontsize=12);
    plt.yticks(fontsize=12);
    plt.xlabel(var_col, fontsize=15)
    plt.ylabel("Sale Price", fontsize=15)
    plt.title("Sales Price Scatter Chart", fontsize=20);

# %%
# function for plotting train set boxplot against saleprice
def var_boxplot(var_col):
    train_set.boxplot(column=["saleprice"], by=[var_col], figsize = (10,6))

    plt.xticks(fontsize=12);
    plt.yticks(fontsize=12);
    plt.xlabel(var_col+" Values", fontsize=15)
    plt.ylabel("Sale Price", fontsize=15);

# %% [markdown]
# ## <font color='red'>Although all 81 variables were reviewed, not every variables' plots will be presented in this workbook. A summary table of cleaning history is available [here](#Summary-of-data-handling)</font>

# %% [markdown]
# # <font color='green'>Outliers Cleaning</font>

# %% [markdown]
# ## <font color='green'>lot_area: 2pts > 100K sqft in train & test sets KIV</font>

# %%
var_hist_scatter('lot_area')

# %%
train_set["lot_area"].describe()
# Out:
# count      2046.000000
# mean      10063.843109
# std        6750.068266
# min        1300.000000
# 25%        7500.000000
# 50%        9417.500000
# 75%       11514.250000
# max      159000.000000
# Name: lot_area, dtype: float64

# %%
test_set["lot_area"].describe()
# Out:
# count       879.000000
# mean      10340.920364
# std       10047.335167
# min        1477.000000
# 25%        7298.500000
# 50%        9453.000000
# 75%       11606.500000
# max      215245.000000
# Name: lot_area, dtype: float64

# %%
var_mean = train_set["lot_area"].mean()
var_std = train_set["lot_area"].std()
var_q = train_set["lot_area"].quantile(.9995)

train_set[train_set["lot_area"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 471  2116  906426060           50        RL    159000   Pave       IR2
# 694  2072  905301050           20        RL    115149   Pave       IR2
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 471          Low    AllPub    CulDSac        Sev      ClearCr        Norm
# 694          Low    AllPub    CulDSac        Sev      ClearCr        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 471        Norm      1Fam      1.5Fin             6             7        1958
# 694        Norm      1Fam      1Story             7             5        1971
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 471            2006      Gable   CompShg      Wd Sdng      HdBoard
# 694            2002      Gable   CompShg      Plywood      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 471       BrkCmn         472.0         Gd         TA     CBlock        Gd
# 694        Stone         351.0         TA         TA     CBlock        Gd
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 471        TA            Gd            Rec         697.0            Unf
# 694        TA            Gd            GLQ        1219.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 471           0.0        747.0         1444.0    GasA         Gd           Y
# 694           0.0        424.0         1643.0    GasA         TA           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 471      SBrkr        1444         700                0         2144
# 694      SBrkr        1824           0                0         1824
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 471             0.0             1.0          2          0              4
# 694             1.0             0.0          2          0              2
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 471              1           Gd              7        Typ           2
# 694              1           Gd              5        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 471           TA      Attchd         1958.0           Fin          2.0
# 694           TA      Attchd         1971.0           Unf          2.0
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 471        389.0          TA          TA           Y             0
# 694        739.0          TA          TA           Y           380
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 471             98               0           0             0          0
# 694             48               0           0             0          0
#
#     pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 471    None  None         Shed       500        6     2007       WD
# 694    None  None         None         0        6     2007       WD
#
#      saleprice
# 471     277000
# 694     302000

# %%
var_mean = test_set["lot_area"].mean()
var_std = test_set["lot_area"].std()
var_q = test_set["lot_area"].quantile(.998)

test_set[test_set["lot_area"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 214   957  916176125           20        RL    215245   Pave       IR3
# 307  1571  916125425          190        RL    164660   Grvl       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 214          Low    AllPub     Inside        Sev       Timber        Norm
# 307          HLS    AllPub     Corner        Sev       Timber        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 214        Norm      1Fam      1Story             7             5        1965
# 307        Norm    2fmCon      1.5Fin             5             6        1965
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 214            1965        Hip   CompShg      BrkFace      BrkFace
# 307            1965      Gable   CompShg      Plywood      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 214         None           0.0         TA         TA     CBlock        Gd
# 307         None           0.0         TA         TA     CBlock        TA
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 214        TA            Gd            ALQ          1236            Rec
# 307        TA            Gd            ALQ          1249            BLQ
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 214           820           80           2136    GasW         TA           Y
# 307           147          103           1499    GasA         Ex           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 214      SBrkr        2036           0                0         2036
# 307      SBrkr        1619         167                0         1786
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 214               2               0          2          0              3
# 307               2               0          2          0              3
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 214              1           TA              8        Typ           2
# 307              1           TA              7        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 214           Gd      Attchd         1965.0           RFn            2
# 307           Gd      Attchd         1965.0           Fin            2
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 214          513          TA          TA           Y             0
# 307          529          TA          TA           Y           670
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 214              0               0           0             0          0
# 307              0               0           0             0          0
#
#     pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 214    None  None         None         0        6     2009       WD
# 307    None  None         Shed       700        8     2008       WD

# %% [markdown]
# ## <font color='green'>bsmtfin_sf_1: 2pts > 3K sqft KIV</font>

# %%
var_hist_scatter('bsmtfin_sf_1')

# %%
train_set["bsmtfin_sf_1"].describe()
# Out:
# count    2046.000000
# mean      442.347996
# std       461.195475
# min         0.000000
# 25%         0.000000
# 50%       368.000000
# 75%       733.750000
# max      5644.000000
# Name: bsmtfin_sf_1, dtype: float64

# %%
test_set["bsmtfin_sf_1"].describe()
# Out:
# count     879.000000
# mean      443.397042
# std       442.480223
# min         0.000000
# 25%         0.000000
# 50%       374.000000
# 75%       735.500000
# max      2288.000000
# Name: bsmtfin_sf_1, dtype: float64

# %%
var_mean = train_set["bsmtfin_sf_1"].mean()
var_std = train_set["bsmtfin_sf_1"].std()
var_q = train_set["bsmtfin_sf_1"].quantile(.9995)

train_set[train_set["bsmtfin_sf_1"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 960   1499  908154235           60        RL     63887   Pave       IR3
# 1881  2181  908154195           20        RL     39290   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1881          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1881        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1881        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1881      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1881        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1881            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1881         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1881                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1881          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1881        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1881           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1881           Y           546            484               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 960              0        480      Gd  None         None         0        1
# 1881             0          0    None  None         Elev     17000       10
#
#       yr_sold sale_type  saleprice
# 960      2008       New     160000
# 1881     2007       New     183850

# %%
var_mean = test_set["bsmtfin_sf_1"].mean()
var_std = test_set["bsmtfin_sf_1"].std()
var_q = test_set["bsmtfin_sf_1"].quantile(.998)

test_set[test_set["bsmtfin_sf_1"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 76   2182  908154205           60        RL     40094   Pave       IR1
# 164   433  528110020           20        RL     13693   Pave       Reg
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 76           Bnk    AllPub     Inside        Gtl      Edwards        PosN
# 164          Lvl    AllPub     Inside        Gtl      NridgHt        PosA
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 76         PosN      1Fam      2Story            10             5        2007
# 164        PosA      1Fam      1Story            10             5        2007
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 76             2008        Hip   CompShg      CemntBd      CmentBd
# 164            2007        Hip   CompShg      VinylSd      VinylSd
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 76         Stone         762.0         Ex         TA      PConc        Ex
# 164        Stone         472.0         Ex         TA      PConc        Ex
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 76         TA            Gd            GLQ          2260            Unf
# 164        TA            Gd            GLQ          2288            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 76              0          878           3138    GasA         Ex           Y
# 164             0          342           2630    GasA         Ex           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 76       SBrkr        3138        1538                0         4676
# 164      SBrkr        2674           0                0         2674
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 76                1               0          3          1              3
# 164               2               0          2          1              2
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 76               1           Ex             11        Typ           1
# 164              1           Ex              8        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 76            Gd     BuiltIn         2007.0           Fin            3
# 164           Gd      Attchd         2007.0           Fin            3
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 76           884          TA          TA           Y           208
# 164          762          TA          TA           Y           360
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 76             406               0           0             0          0
# 164             50               0           0             0          0
#
#     pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 76     None  None         None         0       10     2007       New
# 164    None  None         None         0        3     2009       WD

# %% [markdown]
# ## <font color='green'>bsmtfin_sf_2: 2pts > 1200 sqft KIV</font>

# %%
var_hist_scatter('bsmtfin_sf_2')

# %%
train_set["bsmtfin_sf_2"].describe()
# Out:
# count    2046.000000
# mean       47.818671
# std       164.876627
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1474.000000
# Name: bsmtfin_sf_2, dtype: float64

# %%
test_set["bsmtfin_sf_2"].describe()
# Out:
# count     879.000000
# mean       53.835040
# std       178.539854
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1526.000000
# Name: bsmtfin_sf_2, dtype: float64

# %%
var_mean = train_set["bsmtfin_sf_2"].mean()
var_std = train_set["bsmtfin_sf_2"].std()
var_q = train_set["bsmtfin_sf_2"].quantile(.9995)

train_set[train_set["bsmtfin_sf_2"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 770   2093  906201200           60        RL     10380   Pave       IR1
# 1689  2451  528360050           60        RL     17242   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 770           Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 1689          Lvl    AllPub     Inside        Gtl      NoRidge        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 770         Norm      1Fam      2Story             7             5
# 1689        Norm      1Fam      2Story             9             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 770         1986            1987      Gable   CompShg      Plywood
# 1689        1993            1994        Hip   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 770       Plywood      BrkFace         172.0         Gd         TA     CBlock
# 1689      MetalSd      BrkFace         738.0         Gd         Gd      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 770         TA        TA            Gd            LwQ          28.0
# 1689        Ex        TA            Gd            Rec         292.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 770             ALQ        1474.0          0.0         1502.0    GasA
# 1689            GLQ        1393.0         48.0         1733.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 770          Ex           Y      SBrkr        1553        1177
# 1689         Ex           Y      SBrkr        1933        1567
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 770                 0         2730             1.0             0.0          2
# 1689                0         3500             1.0             0.0          3
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 770           1              4              1           Gd              8
# 1689          1              4              1           Ex             11
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 770         Typ           1           TA      Attchd         1987.0
# 1689        Typ           1           TA      Attchd         1993.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 770            Fin          2.0        576.0          TA          TA
# 1689           RFn          3.0        959.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 770            Y           201             96               0           0
# 1689           Y           870             86               0           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 770              0          0    None  MnPrv         None         0        8
# 1689           210          0    None   None         None         0        5
#
#       yr_sold sale_type  saleprice
# 770      2007       WD      301000
# 1689     2006       WD      584500

# %%
var_mean = test_set["bsmtfin_sf_2"].mean()
var_std = test_set["bsmtfin_sf_2"].std()
var_q = test_set["bsmtfin_sf_2"].quantile(.999)

test_set[test_set["bsmtfin_sf_2"] > var_q]
# Out:
#      id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 65  501  528363050           20        RL     10750   Pave       IR1
#
#    land_contour utilities lot_config land_slope neighborhood condition_1  \
# 65          Lvl    AllPub    CulDSac        Gtl      NoRidge        Norm
#
#    condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 65        Norm      1Fam      1Story             8             5        1994
#
#     year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 65            1995        Hip   CompShg      Wd Sdng      Wd Sdng
#
#    mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 65      BrkFace         634.0         Gd         TA      PConc        Gd
#
#    bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 65        TA            Av            BLQ           236            GLQ
#
#     bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 65          1526          262           2024    GasA         Ex           Y
#
#    electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 65      SBrkr        2063           0                0         2063
#
#     bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 65               1               0          2          0              3
#
#     kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 65              1           Gd              7        Typ           2
#
#    fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 65           Gd      Attchd         1994.0           Fin            3
#
#     garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 65          815          TA          TA           Y           182
#
#     open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 65             56               0           0             0          0
#
#    pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 65    None  None         None         0        6     2009       WD

# %% [markdown]
# ## <font color='green'>total_bsmt_sf: 2pts > 4K sqft KIV</font>

# %%
var_hist_scatter('total_bsmt_sf')

# %%
train_set["total_bsmt_sf"].describe()
# Out:
# count    2046.000000
# mean     1056.478006
# std       447.696341
# min         0.000000
# 25%       793.000000
# 50%       994.500000
# 75%      1317.750000
# max      6110.000000
# Name: total_bsmt_sf, dtype: float64

# %%
test_set["total_bsmt_sf"].describe()
# Out:
# count     879.000000
# mean     1036.750853
# std       419.258428
# min         0.000000
# 25%       790.000000
# 50%       975.000000
# 75%      1248.000000
# max      3138.000000
# Name: total_bsmt_sf, dtype: float64

# %%
var_mean = train_set["total_bsmt_sf"].mean()
var_std = train_set["total_bsmt_sf"].std()
var_q = train_set["total_bsmt_sf"].quantile(.9995)

train_set[train_set["total_bsmt_sf"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 960   1499  908154235           60        RL     63887   Pave       IR3
# 1881  2181  908154195           20        RL     39290   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1881          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1881        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1881        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1881      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1881        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1881            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1881         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1881                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1881          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1881        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1881           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1881           Y           546            484               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 960              0        480      Gd  None         None         0        1
# 1881             0          0    None  None         Elev     17000       10
#
#       yr_sold sale_type  saleprice
# 960      2008       New     160000
# 1881     2007       New     183850

# %%
var_mean = test_set["total_bsmt_sf"].mean()
var_std = test_set["total_bsmt_sf"].std()
var_q = test_set["total_bsmt_sf"].quantile(.998)

test_set[test_set["total_bsmt_sf"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 76   2182  908154205           60        RL     40094   Pave       IR1
# 164   433  528110020           20        RL     13693   Pave       Reg
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 76           Bnk    AllPub     Inside        Gtl      Edwards        PosN
# 164          Lvl    AllPub     Inside        Gtl      NridgHt        PosA
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 76         PosN      1Fam      2Story            10             5        2007
# 164        PosA      1Fam      1Story            10             5        2007
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 76             2008        Hip   CompShg      CemntBd      CmentBd
# 164            2007        Hip   CompShg      VinylSd      VinylSd
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 76         Stone         762.0         Ex         TA      PConc        Ex
# 164        Stone         472.0         Ex         TA      PConc        Ex
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 76         TA            Gd            GLQ          2260            Unf
# 164        TA            Gd            GLQ          2288            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 76              0          878           3138    GasA         Ex           Y
# 164             0          342           2630    GasA         Ex           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 76       SBrkr        3138        1538                0         4676
# 164      SBrkr        2674           0                0         2674
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 76                1               0          3          1              3
# 164               2               0          2          1              2
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 76               1           Ex             11        Typ           1
# 164              1           Ex              8        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 76            Gd     BuiltIn         2007.0           Fin            3
# 164           Gd      Attchd         2007.0           Fin            3
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 76           884          TA          TA           Y           208
# 164          762          TA          TA           Y           360
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 76             406               0           0             0          0
# 164             50               0           0             0          0
#
#     pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 76     None  None         None         0       10     2007       New
# 164    None  None         None         0        3     2009       WD

# %% [markdown]
# ## <font color='green'>1st_flr_sf: 2pts > 4K sqft KIV</font>

# %%
var_hist_scatter('1st_flr_sf')

# %%
train_set["1st_flr_sf"].describe()
# Out:
# count    2046.000000
# mean     1164.485826
# std       396.502352
# min       334.000000
# 25%       879.250000
# 50%      1093.000000
# 75%      1404.750000
# max      5095.000000
# Name: 1st_flr_sf, dtype: float64

# %%
test_set["1st_flr_sf"].describe()
# Out:
# count     879.000000
# mean     1148.053470
# std       381.022337
# min       407.000000
# 25%       864.000000
# 50%      1064.000000
# 75%      1358.000000
# max      3138.000000
# Name: 1st_flr_sf, dtype: float64

# %%
var_mean = train_set["1st_flr_sf"].mean()
var_std = train_set["1st_flr_sf"].std()
var_q = train_set["1st_flr_sf"].quantile(.9995)

train_set[train_set["1st_flr_sf"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 960   1499  908154235           60        RL     63887   Pave       IR3
# 1881  2181  908154195           20        RL     39290   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1881          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1881        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1881        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1881      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1881        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1881            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1881         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1881                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1881          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1881        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1881           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1881           Y           546            484               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 960              0        480      Gd  None         None         0        1
# 1881             0          0    None  None         Elev     17000       10
#
#       yr_sold sale_type  saleprice
# 960      2008       New     160000
# 1881     2007       New     183850

# %%
var_mean = test_set["1st_flr_sf"].mean()
var_std = test_set["1st_flr_sf"].std()
var_q = test_set["1st_flr_sf"].quantile(.998)

test_set[test_set["1st_flr_sf"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 76   2182  908154205           60        RL     40094   Pave       IR1
# 164   433  528110020           20        RL     13693   Pave       Reg
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 76           Bnk    AllPub     Inside        Gtl      Edwards        PosN
# 164          Lvl    AllPub     Inside        Gtl      NridgHt        PosA
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 76         PosN      1Fam      2Story            10             5        2007
# 164        PosA      1Fam      1Story            10             5        2007
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 76             2008        Hip   CompShg      CemntBd      CmentBd
# 164            2007        Hip   CompShg      VinylSd      VinylSd
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 76         Stone         762.0         Ex         TA      PConc        Ex
# 164        Stone         472.0         Ex         TA      PConc        Ex
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 76         TA            Gd            GLQ          2260            Unf
# 164        TA            Gd            GLQ          2288            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 76              0          878           3138    GasA         Ex           Y
# 164             0          342           2630    GasA         Ex           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 76       SBrkr        3138        1538                0         4676
# 164      SBrkr        2674           0                0         2674
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 76                1               0          3          1              3
# 164               2               0          2          1              2
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 76               1           Ex             11        Typ           1
# 164              1           Ex              8        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 76            Gd     BuiltIn         2007.0           Fin            3
# 164           Gd      Attchd         2007.0           Fin            3
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 76           884          TA          TA           Y           208
# 164          762          TA          TA           Y           360
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 76             406               0           0             0          0
# 164             50               0           0             0          0
#
#     pool_qc fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 76     None  None         None         0       10     2007       New
# 164    None  None         None         0        3     2009       WD

# %% [markdown]
# ## <font color='green'>gr_liv_area: 2pts > 5K sqft KIV</font>

# %%
var_hist_scatter('gr_liv_area')

# %%
train_set["bsmt_full_bath"].describe()
# Out:
# count    2046.000000
# mean        0.427664
# std         0.522732
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: bsmt_full_bath, dtype: float64

# %%
test_set["gr_liv_area"].describe()
# Out:
# count     879.000000
# mean     1500.531286
# std       517.413260
# min       407.000000
# 25%      1114.000000
# 50%      1436.000000
# 75%      1781.000000
# max      4676.000000
# Name: gr_liv_area, dtype: float64

# %%
var_mean = train_set["gr_liv_area"].mean()
var_std = train_set["gr_liv_area"].std()
var_q = train_set["gr_liv_area"].quantile(.9995)

train_set[train_set["gr_liv_area"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 960   1499  908154235           60        RL     63887   Pave       IR3
# 1881  2181  908154195           20        RL     39290   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1881          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1881        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1881        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1881      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1881        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1881            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1881         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1881                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1881          1              2              1           Ex             15
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 960         Typ           3           Gd      Attchd         2008.0
# 1881        Typ           2           Gd      Attchd         2008.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 960            Fin          2.0       1418.0          TA          TA
# 1881           Fin          3.0       1154.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 960            Y           214            292               0           0
# 1881           Y           546            484               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 960              0        480      Gd  None         None         0        1
# 1881             0          0    None  None         Elev     17000       10
#
#       yr_sold sale_type  saleprice
# 960      2008       New     160000
# 1881     2007       New     183850

# %%
var_mean = test_set["gr_liv_area"].mean()
var_std = test_set["gr_liv_area"].std()
var_q = test_set["gr_liv_area"].quantile(.998)

test_set[test_set["gr_liv_area"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 76   2182  908154205           60        RL     40094   Pave       IR1
# 171  1761  528320050           60        RL     15623   Pave       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 76           Bnk    AllPub     Inside        Gtl      Edwards        PosN
# 171          Lvl    AllPub     Corner        Gtl      NoRidge        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 76         PosN      1Fam      2Story            10             5        2007
# 171        Norm      1Fam      2Story            10             5        1996
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 76             2008        Hip   CompShg      CemntBd      CmentBd
# 171            1996        Hip   CompShg      Wd Sdng      ImStucc
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 76         Stone         762.0         Ex         TA      PConc        Ex
# 171         None           0.0         Gd         TA      PConc        Ex
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 76         TA            Gd            GLQ          2260            Unf
# 171        TA            Av            GLQ          2096            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 76              0          878           3138    GasA         Ex           Y
# 171             0          300           2396    GasA         Ex           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 76       SBrkr        3138        1538                0         4676
# 171      SBrkr        2411        2065                0         4476
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 76                1               0          3          1              3
# 171               1               0          3          1              4
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 76               1           Ex             11        Typ           1
# 171              1           Ex             10        Typ           2
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 76            Gd     BuiltIn         2007.0           Fin            3
# 171           TA      Attchd         1996.0           Fin            3
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 76           884          TA          TA           Y           208
# 171          813          TA          TA           Y           171
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 76             406               0           0             0          0
# 171             78               0           0             0        555
#
#     pool_qc  fence misc_feature  misc_val  mo_sold  yr_sold sale_type
# 76     None   None         None         0       10     2007       New
# 171      Ex  MnPrv         None         0        7     2007       WD

# %% [markdown]
# ## <font color='green'>garage_yr_blt: 1 pt showing 2207, delete abnormal row</font>

# %%
var_hist_scatter('garage_yr_blt')

# %%
train_set["garage_yr_blt"].describe()
# Out:
# count    2046.000000
# mean     1869.374389
# std       452.766633
# min         0.000000
# 25%      1957.000000
# 50%      1978.000000
# 75%      2001.000000
# max      2207.000000
# Name: garage_yr_blt, dtype: float64

# %%
test_set["garage_yr_blt"].describe()
# Out:
# count     879.000000
# mean     1875.594994
# std       436.640608
# min         0.000000
# 25%      1957.000000
# 50%      1977.000000
# 75%      2000.000000
# max      2010.000000
# Name: garage_yr_blt, dtype: float64

# %%
var_mean = train_set["garage_yr_blt"].mean()
var_std = train_set["garage_yr_blt"].std()
var_q = train_set["garage_yr_blt"].quantile(.9995)

train_set[train_set["garage_yr_blt"] > var_q]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 1696  2261  916384070           20        RL      8298   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1696          HLS    AllPub     Inside        Gtl       Timber        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1696        Norm      1Fam      1Story             8             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1696        2006            2007        Hip   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1696      VinylSd         None           0.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1696        Gd        TA            Av            GLQ         583.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1696            Unf           0.0        963.0         1546.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1696         Ex           Y      SBrkr        1564           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1696                0         1564             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1696          0              2              1           Ex              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1696        Typ           1           Gd      Attchd         2207.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1696           RFn          2.0        502.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1696           Y           132              0               0           0
#
#       screen_porch  pool_area pool_qc fence misc_feature  misc_val  mo_sold  \
# 1696             0          0    None  None         None         0        9
#
#       yr_sold sale_type  saleprice
# 1696     2007       New     267300

# %%
train_set.drop([1696], axis=0, inplace=True)

# %% [markdown]
# ## <font color='green'>wood_deck_sf: 2pts > 1400 sqft KIV</font>

# %%
var_hist_scatter('wood_deck_sf')

# %%
train_set["wood_deck_sf"].describe()
# Out:
# count    2045.000000
# mean       93.818582
# std       128.679934
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       168.000000
# max      1424.000000
# Name: wood_deck_sf, dtype: float64

# %%
test_set["wood_deck_sf"].describe()
# Out:
# count    879.000000
# mean      93.560865
# std      121.174306
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%      171.000000
# max      690.000000
# Name: wood_deck_sf, dtype: float64

# %%
var_mean = train_set["wood_deck_sf"].mean()
var_std = train_set["wood_deck_sf"].std()
var_q = train_set["wood_deck_sf"].quantile(.9996)

train_set[train_set["wood_deck_sf"] > var_q]
# Out:
#        id        pid  ms_subclass ms_zoning  lot_area street lot_shape  \
# 966  2294  923229100           80        RL     15957   Pave       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 966          Low    AllPub     Corner        Mod      Mitchel        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 966        Norm      1Fam        SLvl             6             6        1977
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 966            1977      Gable   CompShg      HdBoard      Plywood
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 966         None           0.0         TA         TA      PConc        Gd
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 966        TA            Gd            GLQ        1148.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 966           0.0         96.0         1244.0    GasA         TA           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 966      SBrkr        1356           0                0         1356
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 966             2.0             0.0          2          0              3
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 966              1           TA              6        Typ           1
#
#     fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 966           TA      Attchd         1977.0           Fin          2.0
#
#      garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 966        528.0          TA          TA           Y          1424
#
#      open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 966              0               0           0             0          0
#
#     pool_qc  fence misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 966    None  MnPrv         None         0        9     2007       WD
#
#      saleprice
# 966     188000

# %% [markdown]
# # <font color='green'>Final Model Optimization related cleaning</font>

# %% [markdown]
# ##### <font color='green'>gr_liv_area has the largest coef. Therefore predict price is expected to be sensitive to this feature. There were 2 outliers for this data column. This 2 rows also show up as outliers in bsmtfin_sf_1, 1st_flr_sf, total_bsmt_sf. Therefore these 2 point can be consider as rather abnormal. Before and after model eval shows improvement to R2 and RMSE</font>

# %%
train_set.drop([960,1881], axis=0, inplace=True)

# %% [markdown]
# ##### <font color='green'>gr_liv_area has the largest coef. Therefore predict price is expected to be sensitive to this feature. There were 2 outliers for this data column. This 2 rows also show up as outliers in bsmtfin_sf_1, 1st_flr_sf, total_bsmt_sf. Therefore these 2 point can be consider as rather abnormal. Before and after model eval shows improvement to R2 and RMSE</font>

# %%
train_set.drop([471,694], axis=0, inplace=True)

# %% [markdown]
# ## <font color='green'>Summary of data handling</font>
#
# |Column|Type|Description|Distribution|Correlation to Sale Price|Null Handling %|Outlier Handling %%|Feature Handling|
# |---|---|---|---|---|---|---|---|
# |Id|int|Property Id|random|None|||exclude from model features|
# |pid|int|Parcel identification number|con't, nominal|None|||exclude from model features|
# |ms_subclass|int|Identifies the type of dwelling involved in the sale|discrete, nominal|Higher price for newer||||
# |ms_zoning|object|Identifies the general zoning classification of the sale|nominal|Higher price for some zones||||
# |lot_frontage|float|Linear feet of street connected to property|con't, Normal|+ve|insufficient domain knowledge to conduct null imputation||exclude from model features|
# |lot_area|int|Lot size in square feet|con't, right skewed|+ve||||
# |street|object|Type of road access to property|nominal|higher price for paved||2pts>100K sqft KIV||
# |alley|object|Type of alley access to property|nominal|higher price for paved|insufficient domain knowledge to conduct null imputation||exclude from model features|
# |lot_shape|object|General shape of property|ordinal|none||||
# |land_contour|object|Flatness of the property|nominal|Higher price for some cat||||
# |utilities|object|Type of utilities available|ordinal|Higher price for some cat||||
# |lot_config|object|Lot configuration|nominal|None||||
# |land_slope|object|Slope of property|ordinal|None||||
# |neighborhood|object|Physical locations within Ames city limits|nominal|Higher prices for some cat||||
# |condition_1|object|Proximity to various conditions|nominal|Higher prices for some cat||||
# |condition_2|object|Proximity to various conditions (if more than one is present)|nominal|Higher prices for some cat||||
# |bldg_type|object|Type of dwelling|nominal|Higher prices for some cat||||
# |house_style|object|Style of dwelling|nominal|Higher prices for some cat||||
# |overall_qual|int|Rates the overall material and finish of the house|discrete, ordinal|+ve||||
# |overall_cond|int|Rates the overall condition of the house|discrete, ordinal|weak +ve||||
# |year_built|int|Original construction date|discrete, left skewed|+ve||||
# |year_remod/add|int|Remodel date (same as construction date if no remodeling or additions)|discrete, left/right skewed|+ve||||
# |roof_style|object|Type of roof|nominal|Higher prices for some cat||||
# |roof_matl|object|Roof material|nominal|Higher prices for some cat||||
# |exterior_1st|object|Exterior covering on house|nominal|Higher prices for some cat||||
# |exterior_2nd|object|Exterior covering on house (if more than one material)|nominal|Higher prices for some cat||||
# |mas_vnr_type|object|Masonry veneer type|nominal|Higher prices for some cat|Null to None|||
# |mas_vnr_area|float|Masonry veneer area in square feet|con't, many Zeros for none|+ve|Null to 0|||
# |exter_qual|object|Evaluates the quality of the material on the exterior|ordinal|Higher prices for some cat||||
# |exter_cond|object|Evaluates the present condition of the material on the exterior|ordinal|Higher prices for some cat||||
# |foundation|object|Type of foundation|nominal|Higher prices for some cat||||
# |bsmt_qual|object|Evaluates the height of the basement|ordinal|Higher prices for some cat|Null to NA|||
# |bsmt_cond|object|Evaluates the general condition of the basement|ordinal|Higher prices for some cat|Null to NA|||
# |bsmt_exposure|object|Refers to walkout or garden level walls|ordinal|Higher prices for some cat|Null to NA|||
# |bsmtfin_type_1|object|Rating of basement finished area|ordinal|Higher prices for some cat|Null to NA|||
# |bsmtfin_sf_1|float, int|Type 1 finished square feet|con't, many Zeros for none|+ve|Null to 0|2pts>12K sqft KIV||
# |bsmtfin_type_2|object|Rating of basement finished area (if multiple types)|ordinal|Higher prices for some cat|Null to NA|||
# |bsmtfin_sf_2|float, int|Type 2 finished square feet|con't, many Zeros for none|weak +ve|Null to 0|2pts>1200 sqft KIV||
# |bsmt_unf_sf|float, int|Unfinished square feet of basement area|con't, right skewed|weak +ve|Null to 0|||
# |total_bsmt_sf|float, int|Total square feet of basement area|con't, normal|+ve|Null to 0|2pts>4K sqft KIV||
# |heating|object|Type of heating|nominal|Higher prices for some cat||||
# |heating_qc|object|Heating quality and condition|ordinal|Higher prices for some cat||||
# |central_air|object|Central air conditioning|nominal|Higher prices for some cat||||
# |electrical|object|Electrical system|ordinal|Higher prices for some cat|delete Null row|||
# |1st_flr_sf|int|First Floor square feet|con't, normal|+ve||2pts>4K sqft KIV||
# |2nd_flr_sf|int|Second floor square feet|con't, many zeros|+ve||||
# |low_qual_fin_sf|int|Low quality finished square feet (all floors)|con't, many zeros|weak +ve||||
# |gr_liv_area|int|Above grade (ground) living area square feet|con't, normal|+ve||2pts>5K sqft KIV||
# |bsmt_full_bath|float, int|Basement full bathrooms|discrete, ordinal|Higher prices for some cat|Null to 0|||
# |bsmt_half_bath|float, int|Basement half bathrooms|discrete, ordinal|Higher prices for some cat|Null to 0|||
# |full_bath|int|Full bathrooms above grade|discrete, ordinal|Higher prices for some cat||||
# |half_bath|int|Half baths above grade|discrete, ordinal|Higher prices for some cat||||
# |bedroom_abvgr|int|Bedrooms above grade (does NOT include basement bedrooms)|discrete, ordinal|Higher prices for some cat||||
# |kitchen_abvgr|int|Kitchens above grade|discrete, ordinal|Higher prices for some cat||||
# |kitchen_qual|object|Kitchen quality|ordinal|Higher prices for some cat||||
# |totrms_abvgrd|int|Total rooms above grade (does not include bathrooms)|discrete, ordinal|Higher prices for some cat||||
# |functional|object|Home functionality (Assume typical unless deductions are warranted)|ordinal|Higher prices for some cat||||
# |fireplaces|int|Number of fireplaces|discrete, ordinal|Higher prices for some cat||||
# |fireplace_qu|object|Fireplace quality|ordinal|Higher prices for some cat|Null to NA|||
# |garage_type|object|Garage location|nominal|Higher prices for some cat|Null to NA|||
# |garage_yr_blt|float|Year garage was built|discrete, ordinal|Higher prices for some cat|Null to 0|delete pt=2207||
# |garage_finish|object|Interior finish of the garage|ordinal|Higher prices for some cat|Null to NA|||
# |garage_cars|float, int|Size of garage in car capacity|discrete, ordinal|Higher prices for some cat|Null to 0|||
# |garage_area|float, int|Size of garage in square feet|con't, normal|+ve|Null to 0|||
# |garage_qual|object|Garage quality|ordinal|Higher prices for some cat|Null to NA|||
# |garage_cond|object|Garage condition|ordinal|Higher prices for some cat|Null to NA|||
# |paved_drive|object|Paved driveway|ordinal|Higher prices for some cat||||
# |wood_deck_sf|int|Wood deck area in square feet|con't, normal|+ve||1pt>1400 sqft KIV||
# |open_porch_sf|int|Open porch area in square feet|con't, normal|+ve||||
# |enclosed_porch|int|Enclosed porch area in square feet|con't, normal|+ve||||
# |3ssn_porch|int|Three season porch area in square feet|con't, normal|weak +ve||||
# |screen_porch|int|Screen porch area in square feet|con't, normal|weak +ve||||
# |pool_area|int|Pool area in square feet|con't, many zeros|weak +ve||||
# |pool_qc|object|Pool quality|ordinal|Higher prices for some cat|Null to NA|||
# |fence|object|Fence quality|ordinal|Higher prices for some cat|Null to NA|||
# |misc_feature|object|Miscellaneous feature not covered in other categories|nominal|Higher prices for some cat|Null to NA|||
# |misc_val|int|$Value of miscellaneous feature|con't, many zeros|weak +ve||||
# |mo_sold|int|Month Sold (MM)|discrete, uniform|||||
# |yr_sold|int|Year Sold (YYYY)|discrete, uniform|||||
# |sale_type|object|Type of sale|nominal|Higher prices for some cat||||
# |saleprice|int|Sale price $$|con't, normal|||||
#
# % Blank indicates no null values<br>
# %% Blank indicates no outliers values

# %% [markdown]
# # <font color='green'>Export No Null/No Outliers datasets</font>

# %%
# Export partially cleaned train and test sets to data folder
train_set.to_csv('../datasets/Output Data/train_noNullnoOut.csv', index=False)
test_set.to_csv('../datasets/Output Data/test_noNullnoOut.csv', index=False)
